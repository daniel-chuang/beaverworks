# %% [markdown]
# # Pizza Shop
# You work at a pizza restaurant, which is starting to accept orders online. You need to
# provide a python function that will accept an arbitrary order as its arguments,
# and compute the correct price for the order.
#
# Your cost-calculator function should have four arguments:
# - pizzas
# - drinks
# - wings
# - coupon
#
#
# A single pizza order is formed as a list of toppings. For example
# - A pizza with no toppings (other than cheese and sauce is: [] (an empty list)
# - A pizza with pepperoni and a double order of olives is : ["pepperoni", "olives", "olives"]
#
# *An arbitrary number of pizzas may be ordered, including no pizzas as all*
#
# Drinks come in as a named order (i.e. a keyword argument 'drinks'). If drinks are ordered,
# they are specified as a list of sizes (possible sizes: "small", "medium", "large", "tub"). For example, `drinks=["small", "small", "large"]` would indicate an order including two small drinks and a large drink.
#
# Wings come in as a named order as well (keyword argument 'wings'). If wings are ordered,
# they are specified as a list of integers (possible sizes: 10, 20, 40, 100). For example, `wings=[20]` would indicate a single order of 20-piece wings.
#
# A coupon may be specified as the keyword argument 'coupon'. It is will be a single
# floating point number between 0 and 1. This indicates the fraction of the *pre-tax*
# price that is to be subtracted. For example `coupon=.25` would indicate a 25%-off coupon.
#
# A 6.25% tax is applied to every order. The tax is computed on the total cost of the
# order *before a coupon is applied*
#
# Round the price to the nearest cent, using the built-in function round. `round(x, 2)` will round `x` to two decimal places.
#
# ## Prices
# The prices are as follows:
#
# **Pizza**
# - \$13.00
#
# **Toppings**
# - pepperoni : \$1.00
# - mushroom : \$0.50
# - olive : \$0.50
# - anchovy : \$2.00
# - ham : \$1.50
#
# **Drinks**
# - small : \$2.00
# - medium : \$3.00
# - large : \$3.50
# - tub : \$3.75
#
# **Wings**
# - 10 : \$5.00
# - 20 : \$9.00
# - 40 : \$17.50
# - 100 : \$48.00
#
#
# ## Examples
# The following is an order for a plain pizza, a ham and anchovy pizza, two "tub"-sized
# drinks, with a 10%-off coupon:
# ```python
# >>>cost_calculator([], ["ham", "anchovy"], drinks=["tub", "tub"], coupon=0.1)
# 35.61
# ```
#
# This order consists only of a small drink.
# ```python
# >>> cost_calculator(drinks=["small"])
# 2.12
# ```
#
# This is an order of two plain pizzas, a pizza with double-pepperoni, an order of a 10-piece and a 20-piece wings, and a small drink.
# ```python
# >>> cost_calculator([], [], ["pepperoni", "pepperoni"], wings=[10, 20], drinks=["small"])
# 60.56
# ```
#
# ## Details
# You can assume that the front-end of the website will never pass your function erroneous
# orders. That is, you will never receive orders for items that do not exist nor
# items that contain typos.
#
# Consider defining individual functions responsible for computing
# the cost of the pizzas, drinks, and wings, respectively. Have `cost_calculator`
# invoke these internally. Alternatively, you can read ahead about dictionaries and make nice
# use of these in this problem.
#
# Our `cost_calculator` signature is empty. Part of the assignment is to come up with the
# correct function signature!

# %%
# make sure to execute this cell so that your function is defined
# you must re-run this cell any time you make a change to this function

"""
**Pizza**
- \$13.00

**Toppings**
- pepperoni : \$1.00
- mushroom : \$0.50
- olive : \$0.50
- anchovy : \$2.00
- ham : \$1.50

**Drinks**
- small : \$2.00
- medium : \$3.00
- large : \$3.50
- tub : \$3.75

**Wings**
- 10 : \$5.00
- 20 : \$9.00
- 40 : \$17.50
- 100 : \$48.00
"""

def cost_calculator(*pizzas, wings=[], drinks=[], coupon=0.0):
    # write your code here
    # be sure to include a `return` statement so that
    # your function returns the appropriate object.
    print(pizzas, drinks, wings, coupon)
    # Set up the original cost and the prices for things
    cost = 0.0
    topping_costs = {"pepperoni":1.0, "mushroom":0.50, "olive":0.50, "anchovy":2.00, "ham":1.50}
    drink_costs = {"small":2.0, "medium":3.0, "large":3.5,"tub":3.75}
    wings_cost = {10:5.0, 20:9.0, 40:17.50,100:48.00}

    # Loops through the pizzas
    for pizza in pizzas:
        cost += 13.0 # Base cost of pizza
        for topping in pizza:
            cost += topping_costs[topping]

    # Loops through the drinks
    for drink in drinks:
        cost += drink_costs[drink]

    # Loops through the wings
    for wing in wings:
        cost += wings_cost[wing]

    taxed_cost = cost*1.0625

    discounted_cost = cost * coupon

    cost = round(taxed_cost - discounted_cost, 2)

    return cost

# %%
# Execute this cell to grade your work
from bwsi_grader.python.pizza_shop import grader
grader(cost_calculator)
# Out:
# om'], ['pepperoni', 'olive', 'mushroom'], []) ['large'] [] 0.0
# ([],) ['medium', 'tub', 'medium'] [] 0.0
# (['ham'], ['anchovy']) ['medium', 'small', 'large'] [100] 0.0
# (['anchovy', 'pepperoni'], ['olive', 'ham', 'ham']) ['tub', 'tub'] [40] 0.0
# (['ham', 'ham'], ['ham']) ['small'] [40, 20, 20] 0.0
# (['mushroom', 'olive'], [], ['olive', 'pepperoni', 'mushroom'], ['ham', 'pepperoni', 'olive']) ['small', 'large'] [40, 40] 0.0
# (['olive', 'olive', 'olive'],) ['tub'] [] 0.0
# (['ham', 'mushroom', 'anchovy'], ['anchovy'], ['ham', 'ham', 'anchovy']) ['small', 'large'] [20, 40, 10] 0.0
# (['pepperoni', 'ham', 'anchovy'],) ['large', 'small', 'large'] [20, 10] 0.0
# (['pepperoni'],) ['medium', 'small'] [10] 0.0
# ([], [], ['olive', 'anchovy']) ['tub', 'small'] [100, 40, 40] 0.0
# (['ham', 'anchovy', 'olive'], ['pepperoni', 'pepperoni', 'ham'], []) [] [] 0.0
# () ['medium'] [40, 40] 0.0
# (['mushroom', 'mushroom', 'ham'], [], ['mushroom'], ['anchovy']) ['small', 'large'] [100, 20] 0.0
# (['pepperoni', 'anchovy'], [], ['olive', 'ham']) ['tub', 'medium'] [20, 40] 0.0
# () ['large', 'large', 'large'] [] 0.0
# (['olive', 'mushroom'], ['ham', 'pepperoni']) [] [] 0.0
# ([],) ['tub'] [100, 40] 0.0
# ([], [], ['pepperoni', 'olive'], ['anchovy', 'mushroom']) ['tub', 'tub'] [100, 40, 100] 0.0
# () ['large', 'medium', 'medium'] [100] 0.0
# (['olive', 'anchovy', 'ham'], [], ['olive', 'pepperoni']) ['small'] [20, 100] 0.0
# (['pepperoni', 'mushroom', 'pepperoni'], ['ham', 'olive'], ['mushroom'], []) ['medium'] [20, 100] 0.0
# (['mushroom'], ['anchovy'], ['pepperoni', 'anchovy'], ['pepperoni', 'anchovy']) ['large', 'tub'] [40] 0.0
# (['anchovy', 'ham', 'anchovy'], [], ['pepperoni', 'olive']) ['large'] [] 0.0
# () ['tub'] [40, 10] 0.0
# (['pepperoni', 'anchovy'], ['ham', 'olive'], ['mushroom']) ['medium', 'medium', 'medium'] [] 0.0
# ([], [], ['mushroom'], []) ['tub', 'medium', 'small'] [100, 100, 100] 0.0
# (['mushroom', 'pepperoni'], ['anchovy', 'anchovy', 'mushroom'], ['anchovy', 'anchovy']) ['large'] [] 0.0
# ([], ['mushroom', 'pepperoni', 'olive'], ['ham', 'ham', 'mushroom']) ['medium', 'small'] [10, 100] 0.0
# (['anchovy'], ['ham', 'ham', 'mushroom'], ['pepperoni', 'pepperoni']) ['tub', 'medium', 'small'] [] 0.0
# (['olive', 'anchovy', 'pepperoni'], [], ['mushroom']) ['large', 'large'] [] 0.0
# (['mushroom'], ['ham', 'ham', 'olive']) ['medium', 'medium', 'medium'] [20] 0.0
# (['mushroom', 'ham', 'mushroom'], [], ['mushroom', 'anchovy', 'olive']) ['small'] [100, 10, 100] 0.0
# ([],) ['tub', 'large'] [40, 40, 10] 0.0
# (['mushroom', 'anchovy', 'pepperoni'], ['olive', 'anchovy', 'pepperoni'], ['pepperoni'], ['olive']) ['small', 'small', 'medium'] [10] 0.0
# () ['tub', 'tub'] [] 0.0
# (['mushroom', 'pepperoni'], ['anchovy'], ['pepperoni']) [] [] 0.0
# ([], ['olive']) ['large', 'small'] [] 0.0
# ([], [], ['anchovy', 'olive'], []) [] [40, 20, 10] 0.0
# (['pepperoni', 'anchovy', 'anchovy'], [], ['ham', 'olive'], []) ['small', 'medium'] [100] 0.0
# (['olive', 'mushroom', 'anchovy'], [], []) [] [] 0.0
# (['mushroom'], ['mushroom', 'ham']) ['tub'] [100, 20, 100] 0.0
# (['pepperoni', 'ham', 'olive'], ['mushroom'], ['pepperoni', 'mushroom', 'mushroom']) ['small', 'tub', 'tub'] [100] 0.0
# () [] [40] 0.0
# () ['medium', 'large', 'small'] [100, 20, 10] 0.0
# (['anchovy', 'mushroom'], []) ['tub', 'small', 'small'] [10, 10, 20] 0.0
# () ['large', 'tub'] [10] 0.0
# ([], ['ham'], [], ['mushroom', 'mushroom']) [] [40, 100, 20] 0.0
# (['pepperoni', 'mushroom', 'pepperoni'],) ['large', 'small', 'large'] [] 0.0
# (['pepperoni', 'ham', 'olive'], ['anchovy'], ['pepperoni', 'ham', 'ham']) ['large', 'tub'] [10, 40] 0.0
# ([], ['pepperoni']) ['medium', 'medium', 'small'] [100, 40] 0.0
# (['ham', 'ham'],) [] [100] 0.0
# (['mushroom'], ['olive'], ['mushroom'], ['pepperoni']) [] [40, 10, 10] 0.0
# (['ham'], ['ham', 'olive'], ['ham', 'anchovy'], []) ['tub', 'small'] [40] 0.0
# ([], ['olive', 'ham'], ['anchovy'], ['mushroom', 'ham']) ['large', 'tub', 'large'] [10, 20, 100] 0.0
# ([], ['mushroom', 'mushroom', 'mushroom'], ['olive', 'pepperoni', 'mushroom'], ['olive']) [] [10] 0.0
# () [] [10] 0.0
# (['pepperoni', 'olive', 'mushroom'],) ['small', 'large', 'small'] [100, 40] 0.0
# (['pepperoni', 'ham', 'ham'], ['mushroom', 'ham']) ['small'] [40, 20] 0.0
# () [] [] 0.0
# (['pepperoni', 'ham', 'mushroom'], ['anchovy'], ['mushroom'], []) ['large'] [100, 40, 100] 0.0
# (['anchovy'], ['anchovy', 'ham'], ['anchovy', 'mushroom', 'pepperoni'], []) [] [] 0.0
# ([], ['mushroom'], ['anchovy']) ['small', 'medium'] [100, 40, 10] 0.0
# () ['medium'] [20, 10] 0.0
# (['mushroom'], ['mushroom', 'ham']) [] [10, 10, 10] 0.0
# (['anchovy', 'ham', 'ham'], ['mushroom'], ['pepperoni'], ['mushroom']) ['tub', 'tub'] [] 0.0
# (['mushroom'], ['ham', 'ham'], ['mushroom']) ['large'] [40] 0.0
# () ['small'] [40, 100] 0.0
# (['pepperoni', 'ham'], ['pepperoni', 'ham']) [] [] 0.0
# () [] [100, 10, 40] 0.0
# (['pepperoni', 'pepperoni'], ['anchovy', 'anchovy'], ['olive', 'olive']) [] [100, 20, 40] 0.0
# (['mushroom', 'mushroom', 'pepperoni'], [], [], []) ['small', 'tub', 'small'] [20, 100, 20] 0.0
# (['mushroom'], ['mushroom', 'olive'], ['pepperoni', 'ham', 'anchovy'], ['mushroom', 'pepperoni', 'pepperoni']) ['large', 'medium', 'tub'] [100] 0.0
# () ['large', 'medium', 'medium'] [20] 0.0
# (['olive'], []) ['tub', 'tub', 'large'] [] 0.0
# (['anchovy', 'anchovy', 'mushroom'],) ['tub', 'large', 'large'] [10] 0.0
# ([], [], []) ['small', 'medium', 'large'] [100] 0.0
# (['pepperoni', 'olive', 'pepperoni'],) ['large', 'large'] [40, 10] 0.0
# () [] [] 0.0
# (['pepperoni', 'mushroom', 'pepperoni'], [], ['mushroom']) ['small', 'small', 'medium'] [40] 0.0
# () ['tub', 'small', 'tub'] [20, 20, 100] 0.0
# (['ham', 'ham'], ['anchovy'], [], []) ['medium', 'large'] [20] 0.0
# () ['small', 'large', 'tub'] [20, 10, 10] 0.0
# (['mushroom', 'pepperoni', 'pepperoni'],) ['large'] [100] 0.0
# (['pepperoni', 'mushroom'],) ['tub'] [] 0.0
# (['olive', 'olive'], ['mushroom'], []) [] [40, 40] 0.0
# (['olive'],) ['tub'] [] 0.0
# ([],) [] [] 0.0
# () ['large', 'medium'] [] 0.0
# (['ham', 'pepperoni', 'pepperoni'], []) ['tub', 'small', 'small'] [10] 0.0
# ([], ['anchovy', 'mushroom'], ['anchovy']) ['large', 'large', 'large'] [] 0.0
# (['olive'],) ['tub', 'small', 'medium'] [100, 10] 0.0
# (['mushroom', 'ham', 'anchovy'], ['ham', 'anchovy', 'anchovy'], ['ham', 'mushroom'], ['pepperoni']) ['large', 'tub', 'tub'] [] 0.0
# (['mushroom', 'mushroom'],) [] [40, 100] 0.0
# (['olive'], ['mushroom', 'olive', 'mushroom'], ['olive', 'mushroom'], ['mushroom']) [] [10, 10, 10] 0.0
# (['ham', 'olive'], [], ['mushroom', 'olive'], ['olive', 'anchovy']) [] [] 0.0
# ([],) ['small'] [20, 100] 0.0
# (['mushroom', 'ham'], ['anchovy', 'anchovy', 'olive']) [] [] 0.0
# ([],) ['medium', 'small', 'tub'] [10, 10, 10] 0.0
# ([],) ['small', 'large', 'medium'] [40, 40, 100] 0.0
# () ['small', 'tub', 'tub'] [20] 0.0
# (['ham', 'ham', 'anchovy'],) ['tub', 'small', 'large'] [] 0.0
# (['pepperoni', 'anchovy', 'anchovy'], ['ham'], []) ['large', 'large', 'medium'] [] 0.0
# (['pepperoni', 'anchovy'], ['mushroom'], [], ['anchovy', 'anchovy']) ['tub'] [] 0.0
# () [] [] 0.0
# (['anchovy', 'ham', 'mushroom'],) ['medium', 'medium'] [40, 100, 10] 0.0
# (['olive', 'pepperoni', 'mushroom'], ['anchovy', 'pepperoni', 'pepperoni']) ['medium', 'large'] [] 0.0
# ([],) ['small', 'medium', 'tub'] [40, 100, 20] 0.0
# ([], ['mushroom', 'anchovy', 'olive'], ['ham']) ['large', 'medium'] [40, 100] 0.0
# (['anchovy'], ['olive', 'pepperoni', 'mushroom'], ['mushroom', 'mushroom'], ['olive']) ['medium'] [20, 10, 20] 0.0
# ([], ['olive', 'anchovy'], []) [] [40] 0.0
# () [] [20, 100, 10] 0.0
# (['pepperoni', 'olive'], ['anchovy'], [], []) [] [20] 0.0
# ([],) ['medium', 'small', 'medium'] [10] 0.0
# (['pepperoni', 'pepperoni'], ['anchovy', 'anchovy', 'ham'], ['mushroom', 'ham', 'pepperoni']) ['small', 'large', 'small'] [] 0.0
# (['ham', 'pepperoni', 'mushroom'], ['mushroom', 'olive', 'mushroom'], [], ['olive', 'anchovy']) ['small', 'tub', 'tub'] [20] 0.0
# ([], ['olive', 'mushroom', 'pepperoni'], ['anchovy', 'pepperoni'], ['ham', 'pepperoni']) [] [40, 100] 0.0
# (['olive'], ['olive'], ['ham', 'ham', 'ham']) [] [20, 20, 10] 0.0
# (['olive', 'olive', 'mushroom'], ['ham', 'ham', 'anchovy'], ['pepperoni', 'olive'], []) ['small'] [] 0.0
# () [] [] 0.0
# (['anchovy'], ['mushroom', 'pepperoni', 'ham'], ['anchovy', 'anchovy'], ['anchovy', 'pepperoni']) ['medium'] [100, 40, 20] 0.0
# (['mushroom', 'pepperoni', 'mushroom'], ['anchovy', 'olive', 'ham'], [], ['anchovy']) ['large', 'tub', 'medium'] [10, 100, 10] 0.0
# (['anchovy', 'mushroom'],) ['small'] [10] 0.0
# () ['large', 'small', 'large'] [10] 0.0
# (['ham'], ['mushroom'], ['mushroom']) ['small'] [40] 0.0
# (['ham', 'olive', 'mushroom'],) ['small', 'small'] [100, 10, 20] 0.0
# (['olive', 'anchovy'], ['ham', 'anchovy'], ['anchovy', 'olive', 'olive'], ['anchovy', 'anchovy']) ['large', 'large', 'small'] [100] 0.0
# (['ham', 'ham', 'mushroom'], ['mushroom', 'ham'], ['pepperoni'], ['pepperoni']) ['tub', 'tub'] [40] 0.0
# ([], ['olive'], [], ['ham', 'anchovy', 'mushroom']) [] [] 0.0
# (['anchovy', 'anchovy', 'olive'],) [] [10, 40, 40] 0.0
# ([], []) [] [] 0.0
# (['mushroom', 'olive', 'pepperoni'], ['anchovy', 'mushroom']) [] [10, 10, 10] 0.0
# () ['tub', 'tub'] [20, 100, 40] 0.0
# (['mushroom'],) ['large', 'small'] [40] 0.0
# () ['medium'] [40] 0.0
# () [] [] 0.0
# (['olive'],) [] [] 0.0
# (['anchovy'], [], ['pepperoni', 'olive'], ['anchovy']) ['large', 'large'] [20, 20] 0.0
# (['mushroom'], []) [] [20] 0.0
# (['ham', 'mushroom'], ['pepperoni'], []) ['small', 'tub'] [20] 0.0
# (['anchovy', 'olive', 'pepperoni'], ['anchovy', 'ham', 'mushroom'], ['olive'], ['olive']) ['large'] [20, 40, 20] 0.0
# (['ham'], ['ham', 'ham', 'mushroom'], ['anchovy', 'olive', 'olive']) [] [] 0.0
# ([], ['mushroom', 'mushroom', 'ham'], ['anchovy', 'anchovy', 'anchovy'], ['anchovy', 'mushroom', 'ham']) ['large', 'medium'] [10] 0.0
# () [] [20] 0.0
# (['olive'], ['pepperoni', 'anchovy']) ['medium'] [] 0.0
# ([], ['olive']) ['large'] [20, 20, 20] 0.0
# (['anchovy', 'ham'], []) ['large'] [10] 0.0
# (['pepperoni'],) [] [] 0.0
# ([], ['mushroom', 'anchovy', 'pepperoni'], ['olive', 'anchovy', 'pepperoni'], ['mushroom', 'ham']) ['medium', 'medium'] [] 0.0
# () [] [20, 20, 100] 0.0
# (['olive'], [], [], []) ['tub'] [] 0.0
# ([], ['olive', 'mushroom', 'anchovy']) ['large', 'tub'] [10] 0.0
# ([], ['pepperoni', 'olive'], ['mushroom']) [] [100, 10] 0.0
# ([], ['anchovy', 'anchovy', 'olive'], []) ['medium'] [40, 100] 0.0
# (['anchovy'], ['ham'], []) [] [] 0.0
# (['pepperoni', 'olive'], ['pepperoni'], ['ham', 'mushroom', 'mushroom']) [] [20, 20] 0.0
# () ['large', 'medium'] [10, 10] 0.0
# (['mushroom', 'ham'], ['mushroom', 'mushroom', 'mushroom']) [] [100, 100, 40] 0.0
# (['ham', 'pepperoni'], ['olive', 'pepperoni', 'olive'], ['mushroom', 'anchovy', 'ham']) ['large'] [10] 0.0
# ([], ['anchovy'], ['olive'], ['ham']) [] [] 0.0
# ([], ['anchovy'], ['mushroom', 'anchovy']) ['large', 'medium'] [10] 0.0
# (['mushroom', 'olive'],) ['small', 'small', 'tub'] [100] 0.0
# (['pepperoni'], ['olive', 'mushroom', 'anchovy'], []) ['large', 'large'] [20, 100, 20] 0.0
# (['anchovy', 'mushroom'], ['ham'], ['anchovy', 'anchovy', 'pepperoni'], ['olive', 'ham', 'pepperoni']) ['large'] [20, 10] 0.0
# ([], ['pepperoni', 'mushroom', 'anchovy'], ['olive', 'anchovy', 'anchovy']) ['medium'] [10, 20] 0.0
# () ['tub'] [] 0.0
# (['anchovy'],) [] [] 0.0
# ([], ['mushroom'], ['mushroom', 'ham'], ['pepperoni']) [] [100, 20, 100] 0.0
# ([],) ['large'] [40] 0.0
# (['ham', 'pepperoni'], ['olive', 'olive', 'mushroom'], [], []) [] [40, 20, 40] 0.0
# () [] [20] 0.0
# () ['small', 'tub', 'tub'] [] 0.0
# (['anchovy', 'ham', 'mushroom'],) ['medium', 'medium', 'large'] [20, 10] 0.0
# ([], ['pepperoni'], ['mushroom']) ['medium', 'tub', 'large'] [40] 0.0
# (['anchovy', 'ham', 'pepperoni'],) ['large', 'medium', 'medium'] [100, 20, 100] 0.0
# () [] [40, 40] 0.0
# ([], ['pepperoni']) ['tub', 'medium'] [20] 0.0
# (['ham', 'anchovy', 'pepperoni'], []) ['large', 'medium'] [10, 10, 10] 0.0
# ([], ['anchovy', 'mushroom']) ['small', 'medium'] [100, 40, 10] 0.0
# (['mushroom'], ['pepperoni', 'mushroom']) ['tub', 'tub', 'large'] [40, 40, 100] 0.0
# (['pepperoni', 'mushroom'], ['anchovy', 'mushroom', 'mushroom'], ['olive', 'pepperoni']) [] [] 0.0
# (['anchovy'],) ['large', 'large'] [40] 0.0
# (['mushroom'], [], ['mushroom', 'ham']) ['large', 'medium'] [10] 0.0
# ([], ['olive']) ['large', 'tub', 'large'] [10] 0.0
# (['olive', 'mushroom'], ['olive'], ['olive', 'ham'], ['olive', 'mushroom', 'ham']) ['large', 'tub'] [] 0.0
# (['anchovy', 'ham'], ['ham', 'olive', 'ham'], ['anchovy', 'mushroom']) ['small', 'tub', 'tub'] [10, 20, 40] 0.0
# (['mushroom', 'mushroom'], ['olive', 'ham', 'pepperoni'], [], ['ham', 'anchovy']) ['large'] [20, 10, 100] 0.0
# (['anchovy', 'olive'],) [] [10, 10] 0.0
# (['anchovy', 'ham', 'pepperoni'], ['anchovy', 'ham', 'ham']) ['small'] [20, 100] 0.0
# ([],) ['large', 'tub', 'tub'] [40] 0.0
# () ['tub', 'tub', 'tub'] [10, 10] 0.0
# () ['medium'] [40, 10] 0.0
# (['olive', 'ham', 'pepperoni'], ['pepperoni']) ['large', 'tub'] [20, 40, 40] 0.0
# (['mushroom', 'pepperoni', 'mushroom'], ['olive'], ['pepperoni', 'anchovy', 'olive']) ['medium', 'large', 'tub'] [100, 20, 20] 0.0
# (['pepperoni', 'olive'], [], []) ['large', 'small', 'large'] [10, 100] 0.0
# () ['medium', 'small', 'small'] [] 0.0
# (['pepperoni', 'ham'],) ['large', 'large', 'medium'] [10] 0.0
# () [] [40, 40] 0.0
# (['ham', 'mushroom', 'ham'], [], ['mushroom', 'olive', 'anchovy'], ['pepperoni', 'mushroom', 'anchovy']) ['tub', 'medium', 'medium'] [40, 40, 10] 0.0
# (['anchovy'], ['pepperoni', 'mushroom'], ['pepperoni', 'ham'], ['olive', 'anchovy']) [] [40, 40, 100] 0.0
# (['anchovy'],) [] [] 0.0
# (['anchovy'], ['mushroom'], ['pepperoni', 'pepperoni', 'pepperoni']) ['large', 'medium', 'tub'] [20] 0.0
# (['mushroom'],) [] [20, 20] 0.0
# (['mushroom', 'ham'], []) ['small', 'tub'] [40, 40, 100] 0.0
# (['anchovy'], ['ham', 'olive', 'pepperoni'], ['pepperoni', 'ham']) ['small', 'small', 'small'] [40] 0.0
# (['olive', 'olive'],) [] [100, 40] 0.0
# (['ham'],) ['large', 'small'] [20, 100, 40] 0.0
# () ['medium'] [40, 10, 20] 0.0
# ([],) ['tub', 'tub', 'small'] [40] 0.0
# (['pepperoni', 'olive', 'mushroom'], [], []) ['medium'] [20] 0.0
# ([],) ['small', 'tub', 'medium'] [] 0.0
# () ['tub', 'tub', 'large'] [20, 10, 40] 0.0
# () [] [40, 10, 100] 0.0
# ([], ['anchovy', 'mushroom', 'pepperoni'], ['mushroom', 'anchovy', 'mushroom'], []) ['medium', 'medium'] [10, 20] 0.0
# ([], ['olive', 'anchovy', 'anchovy'], ['mushroom'], ['pepperoni']) ['tub'] [] 0.0
# ([],) [] [100, 40, 10] 0.0
# () ['small'] [20, 10] 0.0
# (['olive'], ['mushroom', 'pepperoni']) ['tub', 'small'] [] 0.0
# (['anchovy', 'mushroom'], ['ham'], ['anchovy', 'olive', 'ham']) ['small', 'large'] [10] 0.0
# (['mushroom', 'pepperoni'], ['anchovy', 'ham']) ['tub', 'medium', 'tub'] [] 0.0
# () ['tub', 'tub', 'tub'] [] 0.0
# (['pepperoni'], ['mushroom']) ['medium', 'small'] [] 0.0
# (['mushroom', 'olive'], ['pepperoni', 'mushroom', 'pepperoni'], ['mushroom', 'anchovy'], ['ham']) ['medium', 'tub', 'small'] [40] 0.0
# (['olive', 'ham'],) ['medium'] [] 0.0
# ([], ['anchovy']) ['small', 'small', 'large'] [100, 100] 0.0
# ([], ['pepperoni', 'anchovy'], ['mushroom']) ['tub', 'medium'] [] 0.0
# ([], ['pepperoni'], ['mushroom', 'mushroom']) [] [100, 20] 0.0
# (['olive'], ['olive', 'ham'], [], ['ham', 'olive']) ['medium', 'large'] [] 0.0
# (['anchovy', 'anchovy'], ['mushroom', 'olive', 'ham']) ['tub', 'tub'] [40, 10, 10] 0.0
# (['mushroom'],) [] [10, 10] 0.0
# (['ham'],) ['tub'] [100] 0.0
# (['olive'], ['anchovy', 'ham'], ['ham', 'anchovy']) [] [] 0.0
# () ['medium', 'small', 'tub'] [20, 20, 20] 0.0
# ([], ['olive', 'olive'], ['anchovy', 'olive', 'anchovy']) ['tub', 'large', 'large'] [40] 0.0
# (['ham', 'anchovy'], ['mushroom']) ['medium', 'large'] [] 0.0
# (['mushroom', 'mushroom'], ['pepperoni', 'olive'], ['mushroom', 'olive', 'pepperoni']) ['tub', 'small', 'large'] [10] 0.0
# () ['tub', 'large'] [10] 0.0
# (['ham', 'olive', 'ham'], ['anchovy', 'mushroom'], [], ['olive']) ['tub'] [40, 100] 0.0
# () ['medium', 'medium', 'tub'] [] 0.0
# (['ham'], ['mushroom', 'olive', 'ham']) [] [100, 10] 0.0
# (['anchovy', 'ham'],) ['small'] [10] 0.0
# () ['large', 'medium'] [] 0.0
# (['ham', 'anchovy'], ['ham', 'mushroom', 'mushroom'], ['mushroom', 'mushroom', 'pepperoni'], ['pepperoni', 'pepperoni']) ['large', 'small'] [100, 10, 20] 0.0
# (['mushroom', 'pepperoni', 'anchovy'], ['anchovy', 'anchovy', 'olive'], ['anchovy']) ['large'] [10] 0.0
# () ['medium', 'tub'] [40, 20] 0.0
# ([], ['ham', 'ham'], ['pepperoni']) [] [20, 20] 0.0
# (['pepperoni', 'anchovy'],) [] [20, 20] 0.0
# (['anchovy', 'anchovy', 'olive'],) ['large', 'small'] [40] 0.0
# (['anchovy', 'mushroom'], ['ham', 'anchovy'], []) ['tub', 'small', 'large'] [100, 10] 0.0
# (['olive', 'ham', 'anchovy'], ['anchovy', 'anchovy'], ['pepperoni', 'olive']) [] [10, 40, 100] 0.0
# () ['tub'] [40, 100, 40] 0.0
# (['pepperoni', 'pepperoni', 'ham'],) ['medium', 'large', 'small'] [] 0.0
# (['ham', 'mushroom'], ['anchovy']) [] [] 0.0
# (['mushroom', 'mushroom'], ['pepperoni', 'pepperoni', 'olive']) ['tub'] [] 0.0
# ([], ['anchovy']) ['tub', 'large'] [20, 40] 0.0
# (['mushroom', 'anchovy', 'olive'],) [] [] 0.0
# (['olive'], ['ham'], ['mushroom', 'mushroom'], ['mushroom', 'anchovy']) ['medium', 'small'] [20, 100] 0.0
# (['ham'], ['anchovy', 'anchovy', 'pepperoni'], []) [] [40] 0.0
# (['pepperoni', 'olive', 'olive'], ['anchovy', 'pepperoni', 'ham']) ['small', 'tub'] [40, 10, 20] 0.0
# (['mushroom', 'mushroom'], ['ham', 'mushroom']) [] [40] 0.0
# () ['small', 'small'] [100, 100, 100] 0.0
# ([],) ['tub', 'medium'] [20, 40, 100] 0.0
# (['ham'],) ['large'] [40, 10, 40] 0.0
# () ['small', 'small'] [40] 0.0
# (['mushroom', 'anchovy', 'mushroom'], ['olive', 'mushroom'], [], ['mushroom', 'mushroom', 'mushroom']) ['small', 'large'] [20, 100] 0.0
# (['olive', 'olive'], ['pepperoni', 'olive', 'mushroom']) ['small', 'medium'] [100, 40] 0.0
# (['anchovy'],) ['tub'] [100, 40, 20] 0.0
# (['olive'], ['mushroom'], ['ham'], []) ['small'] [20, 100, 100] 0.0
# () ['small', 'large', 'medium'] [20] 0.0
# (['olive', 'pepperoni'], ['mushroom', 'mushroom', 'olive'], ['olive', 'mushroom', 'pepperoni'], ['olive']) ['small'] [40, 100, 100] 0.0
# (['pepperoni'], ['mushroom', 'olive'], ['olive', 'mushroom'], ['olive', 'mushroom', 'ham']) ['large', 'small'] [40] 0.0
# (['ham', 'ham', 'mushroom'],) ['large', 'small', 'small'] [] 0.0
# () ['large', 'small'] [40] 0.0
# (['olive', 'ham'], ['ham', 'ham', 'mushroom'], ['olive', 'olive', 'pepperoni']) ['large', 'large'] [100] 0.0
# (['mushroom', 'olive', 'anchovy'],) ['tub', 'medium', 'large'] [10, 10] 0.0
# (['pepperoni'], ['pepperoni']) ['tub', 'small'] [] 0.0
# (['mushroom'], ['mushroom', 'anchovy', 'anchovy'], ['pepperoni', 'ham', 'ham'], ['pepperoni', 'pepperoni']) [] [20] 0.0
# ([],) [] [20, 10, 10] 0.0
# (['anchovy', 'mushroom', 'mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'pepperoni', 'pepperoni']) ['large'] [] 0.0
# (['olive', 'mushroom'], ['ham', 'olive', 'mushroom'], ['olive', 'mushroom', 'olive'], ['pepperoni', 'anchovy']) [] [] 0.0
# (['anchovy', 'anchovy', 'olive'], ['anchovy']) ['tub'] [] 0.0
# (['ham'], [], ['olive', 'mushroom']) ['medium', 'tub', 'medium'] [100, 100] 0.0
# ([],) [] [] 0.0
# (['mushroom', 'olive'], ['pepperoni', 'ham', 'anchovy'], ['ham', 'anchovy', 'anchovy']) ['tub', 'medium'] [20] 0.0
# (['olive', 'olive'], ['olive'], ['pepperoni', 'anchovy', 'ham'], ['anchovy', 'pepperoni', 'ham']) ['large'] [40, 100, 20] 0.0
# () ['medium'] [20, 100] 0.0
# (['ham', 'olive'], ['ham', 'olive', 'ham'], ['mushroom', 'ham'], ['pepperoni', 'ham', 'olive']) ['medium', 'large', 'small'] [40] 0.0
# () ['medium'] [] 0.0
# ([], [], ['mushroom', 'ham']) ['medium', 'tub', 'tub'] [] 0.0
# () ['small'] [10, 100] 0.0
# (['pepperoni'], ['mushroom']) ['large', 'medium'] [100] 0.0
# () [] [] 0.0
# () [] [100] 0.0
# (['mushroom', 'mushroom', 'ham'], ['pepperoni']) [] [100, 10, 100] 0.0
# (['mushroom', 'pepperoni'], ['olive']) [] [20] 0.0
# ([], ['olive'], ['ham'], ['pepperoni', 'pepperoni']) ['medium', 'medium'] [20] 0.0
# () ['large'] [] 0.0
# (['mushroom', 'pepperoni', 'olive'], ['ham', 'ham', 'pepperoni']) ['medium', 'medium'] [] 0.0
#
# ============================== ALL TESTS PASSED! ===============================
# Your submission code: bw376a5897c31ca763c949f9e3e3b48926ae5e8e0dfb0210f3f59d4485
# ================================================================================
